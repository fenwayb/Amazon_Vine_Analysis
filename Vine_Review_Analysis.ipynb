# %%
import pandas as pd

# %%
columns = ["review_id", "star_rating", "helpful_votes", "total_votes", "vine", "verified purchase"]
vine_df = pd.read_csv("vine_table.csv", header=None)
vine_df.columns = columns
vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0       R3EFW2STIYIY0I            1              2            2    N
# 1       R12NR0R5A9F7FT            5              0            0    N
# 2       R1LSH74R9XAP59            2              0            1    N
# 3       R1QXUNTF76K7L6            2              0            0    N
# 4       R2F7DR75PS8NKT            5              0            0    N
# ...                ...          ...            ...          ...  ...
# 341926  R22N983F9Y5B7H            5              5            7    N
# 341927   RZ9DND08T95KF            5              3            5    N
# 341928  R3EDTMHC38P95O            4              1            1    N
# 341929  R1LYRNM6CTLUG4            1              0            2    N
# 341930  R21PP8R25RNBKG            3             12           13    N
#
#        verified purchase
# 0                      Y
# 1                      Y
# 2                      Y
# 3                      Y
# ...

# %%
vine_df.dtypes
# Out:
# review_id            object
# star_rating           int64
# helpful_votes         int64
# total_votes           int64
# vine                 object
# verified purchase    object
# dtype: object

# %%
total_votes_df = vine_df[vine_df["total_votes"] >= 20]
total_votes_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 19      R26CC1STPSUHBS            1             27           39    N
# 202      R7K83D59T9KWS            1             16           26    N
# 219     R2ATG5BPVILHUM            1             16           25    N
# 345     R1Q71TAM5ZOYTK            3             57           61    N
# 454      RR8HYI7C2XKMU            5             25           25    N
# ...                ...          ...            ...          ...  ...
# 341915  R1AQGHID4CP5AP            5             23           25    N
# 341916  R3L2BJHIOT18TS            4             25           26    N
# 341919  R22YSF1AKQ49T6            2             21           25    N
# 341920   RE4LNSZWHHPQ4            5             48           59    N
# 341922  R30SHB0N1VNHA1            5             89           89    N
#
#        verified purchase
# 19                     N
# 202                    N
# 219                    N
# 345                    N
# ...

# %%
helpful_df = total_votes_df[total_votes_df["helpful_votes"] / total_votes_df["total_votes"] >= .5]
helpful_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 19      R26CC1STPSUHBS            1             27           39    N
# 202      R7K83D59T9KWS            1             16           26    N
# 219     R2ATG5BPVILHUM            1             16           25    N
# 345     R1Q71TAM5ZOYTK            3             57           61    N
# 454      RR8HYI7C2XKMU            5             25           25    N
# ...                ...          ...            ...          ...  ...
# 341915  R1AQGHID4CP5AP            5             23           25    N
# 341916  R3L2BJHIOT18TS            4             25           26    N
# 341919  R22YSF1AKQ49T6            2             21           25    N
# 341920   RE4LNSZWHHPQ4            5             48           59    N
# 341922  R30SHB0N1VNHA1            5             89           89    N
#
#        verified purchase
# 19                     N
# 202                    N
# 219                    N
# 345                    N
# ...

# %%
paid_df = helpful_df[helpful_df["vine"] == "Y"]
paid_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 11313   R28EIR3Z6RRUNN            2             50           60    Y
# 19233   R2YO2RESXZEWOF            4             24           25    Y
# 30450    R8GEE2EW3D6S9            3             49           54    Y
# 32929   R33W9V1MX6WKPS            4             47           53    Y
# 35028   R24E3W2ZRIFG8C            5             91           93    Y
# ...                ...          ...            ...          ...  ...
# 279002  R355R1K0UUTPVM            5             70           71    Y
# 281003   RH9EI8TTHE45W            5             28           31    Y
# 283280  R1GRNLMBP4CC02            4             23           26    Y
# 283302  R393A45ITWN11F            5             59           63    Y
# 283437   RW9U7VT1GELNS            5             16           20    Y
#
#        verified purchase
# 11313                  N
# 19233                  N
# 30450                  N
# 32929                  N
# ...

# %%
free_df = helpful_df[helpful_df["vine"] == "N"]
free_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 19      R26CC1STPSUHBS            1             27           39    N
# 202      R7K83D59T9KWS            1             16           26    N
# 219     R2ATG5BPVILHUM            1             16           25    N
# 345     R1Q71TAM5ZOYTK            3             57           61    N
# 454      RR8HYI7C2XKMU            5             25           25    N
# ...                ...          ...            ...          ...  ...
# 341915  R1AQGHID4CP5AP            5             23           25    N
# 341916  R3L2BJHIOT18TS            4             25           26    N
# 341919  R22YSF1AKQ49T6            2             21           25    N
# 341920   RE4LNSZWHHPQ4            5             48           59    N
# 341922  R30SHB0N1VNHA1            5             89           89    N
#
#        verified purchase
# 19                     N
# 202                    N
# 219                    N
# 345                    N
# ...

# %%
paid_total = len(paid_df["review_id"])
paid_five = len(paid_df[paid_df["star_rating"] == 5])
paid_per = paid_five/paid_total
paid_per
# Out:
# 0.4112903225806452

# %%
free_total = len(free_df["review_id"])
free_five = len(free_df[free_df["star_rating"] == 5])
free_per = free_five/free_total
free_per
# Out:
# 0.29427886262418634
